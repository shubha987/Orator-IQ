# %%
pip install opencv-python sounddevice transformers torch soundfile numpy
# Out:
# Requirement already satisfied: opencv-python in c:\users\shahj\anaconda3\anaconda\lib\site-packages (4.10.0.84)
# Requirement already satisfied: sounddevice in c:\users\shahj\anaconda3\anaconda\lib\site-packages (0.5.1)
# Requirement already satisfied: transformers in c:\users\shahj\anaconda3\anaconda\lib\site-packages (4.47.0)
# Requirement already satisfied: torch in c:\users\shahj\anaconda3\anaconda\lib\site-packages (2.2.2)
# Requirement already satisfied: soundfile in c:\users\shahj\anaconda3\anaconda\lib\site-packages (0.12.1)
# Requirement already satisfied: numpy in c:\users\shahj\anaconda3\anaconda\lib\site-packages (1.26.4)
# Requirement already satisfied: CFFI>=1.0 in c:\users\shahj\anaconda3\anaconda\lib\site-packages (from sounddevice) (1.17.1)
# Requirement already satisfied: filelock in c:\users\shahj\anaconda3\anaconda\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in c:\users\shahj\anaconda3\anaconda\lib\site-packages (from transformers) (0.26.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\shahj\anaconda3\anaconda\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\shahj\anaconda3\anaconda\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\shahj\anaconda3\anaconda\lib\site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in c:\users\shahj\anaconda3\anaconda\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\shahj\anaconda3\anaconda\lib\site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\shahj\anaconda3\anaconda\lib\site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in c:\users\shahj\anaconda3\anaconda\lib\site-packages (from transformers) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\shahj\anaconda3\anaconda\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in c:\users\shahj\anaconda3\anaconda\lib\site-packages (from torch) (1.13.2)
# Requirement already satisfied: networkx in c:\users\shahj\anaconda3\anaconda\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\shahj\anaconda3\anaconda\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\shahj\anaconda3\anaconda\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: pycparser in c:\users\shahj\anaconda3\anaconda\lib\site-packages (from CFFI>=1.0->sounddevice) (2.21)
# Requirement already satisfied: colorama in c:\users\shahj\anaconda3\anaconda\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\shahj\anaconda3\anaconda\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shahj\anaconda3\anaconda\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shahj\anaconda3\anaconda\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shahj\anaconda3\anaconda\lib\site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shahj\anaconda3\anaconda\lib\site-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\shahj\anaconda3\anaconda\lib\site-packages (from sympy->torch) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import sounddevice as sd
import queue
import torch
from transformers import Wav2Vec2Processor, Wav2Vec2ForCTC

# Global variables for real-time audio processing
audio_queue = queue.Queue()
samplerate = 16000  # Wav2Vec2 requires 16 kHz audio

# Load Wav2Vec2 model and processor
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-base-960h")
model = Wav2Vec2ForCTC.from_pretrained("facebook/wav2vec2-base-960h")

def audio_callback(indata, frames, time, status):
    """
    Callback function to capture audio in real-time.
    """
    if status:
        print(status)
    audio_queue.put(indata.copy())

def transcribe_audio(audio_chunk):
    """
    Transcribe an audio chunk using Wav2Vec2.
    """
    audio_chunk = audio_chunk.flatten()
    # Process the audio chunk using the processor
    inputs = processor(audio_chunk, sampling_rate=samplerate, return_tensors="pt", padding=True)
    
    # Run the model inference with the correct input values
    with torch.no_grad():
        logits = model(inputs.input_values).logits  # Corrected here
    
    # Get the predicted tokens from the model
    predicted_ids = torch.argmax(logits, dim=-1)
    
    # Decode the tokens into human-readable transcription
    transcription = processor.batch_decode(predicted_ids)
    
    return transcription[0]

def main():
    # Open the Camera 
    cap = cv2.VideoCapture(0)
    if not cap.isOpened():
        print("Error: Could not open webcam.")
        return

    # Start Audio Stream
    with sd.InputStream(samplerate=samplerate, channels=1, callback=audio_callback):
        print("Recording video and audio. Press 'q' to stop.")
        
        while True:
            # Capture video frame
            ret, frame = cap.read()
            if not ret:
                break

            cv2.imshow("Real-Time Transcription", frame)
            
            # Process audio chunks for transcription
            if not audio_queue.empty():
                audio_chunk = audio_queue.get()
                try:
                    transcription = transcribe_audio(audio_chunk)
                    print("Transcription:", transcription)
                except Exception as e:
                    print(f"Error during transcription: {e}")

            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
    
    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    main()
# Out:
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-base-960h and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Recording video and audio. Press 'q' to stop.
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
# Transcription:
